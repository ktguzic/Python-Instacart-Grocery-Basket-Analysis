# %% [markdown]
# # customer_data wrangling and checks and merge wtih ords_prods_merge dataframe

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
#path import
path = r'C:\Users\guzic\Contacts\Instacart Grocery Basket Analysis'

# %%
# original customer data csv file import

customer_data = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'))

# %%
# import check

customer_data.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# checks

customer_data.shape
# Out:
# (206209, 10)

# %%
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   First Name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   STATE         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %%
customer_data.describe()
# Out:
#              user_id            Age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
# data wrangling

# drop any columns?

# Rename any columns?

# Change data type?

# Transpose data?

# check for mixed type data

# check for missing values

# check for duplicates

# data dictionary?

# subsetting?

# indexing

# %%
# drop any columns? - Not at this time. Would like to know if it was ethical how we got some of the info

# %%
# rename any columns?

# First Name - first_name
# Surnam - last_name
# Gender - gender
# STATE - state
# Age - age
# date_joined
# n_dependants - dependants
# fam_status
# income

# %%
customer_data.rename(columns = {'First Name' : 'first_name'}, inplace = True)

# %%
# check 
customer_data.columns
# Out:
# Index(['user_id', 'first_name', 'Surnam', 'Gender', 'STATE', 'Age',
#        'date_joined', 'n_dependants', 'fam_status', 'income'],
#       dtype='object')

# %%
# changing rest of the columns

customer_data.rename(columns = {'Surnam' : 'last_name'}, inplace = True)
customer_data.rename(columns = {'Gender' : 'gender'}, inplace = True)
customer_data.rename(columns = {'STATE' : 'state'}, inplace = True)
customer_data.rename(columns = {'Age' : 'age'}, inplace = True)
customer_data.rename(columns = {'n_dependants' : 'dependants'}, inplace = True)

# %%
# check 

customer_data.columns
# Out:
# Index(['user_id', 'first_name', 'last_name', 'gender', 'state', 'age',
#        'date_joined', 'dependants', 'fam_status', 'income'],
#       dtype='object')

# %%
# Change data type?

customer_data.describe()
# Out:
#              user_id            age     dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
# user_id to be changed to .str

customer_data['user_id'] = customer_data['user_id'].astype('str')

# %%
# check - No longer on the chart

customer_data.describe()
# Out:
#                  age     dependants         income
# count  206209.000000  206209.000000  206209.000000
# mean       49.501646       1.499823   94632.852548
# std        18.480962       1.118433   42473.786988
# min        18.000000       0.000000   25903.000000
# 25%        33.000000       0.000000   59874.000000
# 50%        49.000000       1.000000   93547.000000
# 75%        66.000000       3.000000  124244.000000
# max        81.000000       3.000000  593901.000000

# %%
# Transpose data? - No need in this case as the dataframe is the "wide view", which works in this case

# %%
customer_data.head()
# Out:
#   user_id first_name last_name  gender       state  age date_joined  \
# 0   26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1   33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2   65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3  125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4  130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    dependants fam_status  income
# 0           3    married  165665
# 1           0     single   59285
# 2           2    married   99568
# 3           0     single   42049
# 4           1    married   40374

# %%
# check for mixed type data - None in this case

# %%
# check for missing values

customer_data.isnull().sum()
# Out:
# user_id            0
# first_name     11259
# last_name          0
# gender             0
# state              0
# age                0
# date_joined        0
# dependants         0
# fam_status         0
# income             0
# dtype: int64

# %%
customer_data_nan = customer_data[customer_data['first_name'].isnull()== True]

# %%
customer_data_nan
# Out:
#        user_id first_name last_name  gender         state  age date_joined  \
# 53       76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73       13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82       89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99       96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105      29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...        ...        ...       ...     ...           ...  ...         ...
# 206038  121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044  200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090  167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162  187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171  116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         dependants fam_status  income
# ...

# %%
# I don't think we should get rid of all the rows without a first name as perhaps they did not add their first
# name when ordering or something like that. Rather, let's change the NaN to a flag - "Not Provided". The rest of the
# information is prudent and you can still get a hold of someone with just their last name and the rest of the info

# %%
# changing the first name NaN points to: 'Not Provided'

customer_data['first_name'].fillna('Not Provided', inplace=True)

# %%
# check
customer_data.isnull().sum()
# Out:
# user_id        0
# first_name     0
# last_name      0
# gender         0
# state          0
# age            0
# date_joined    0
# dependants     0
# fam_status     0
# income         0
# dtype: int64

# %%
# shape check

customer_data.shape
# Out:
# (206209, 10)

# %%
# duplicates check

dups = customer_data[customer_data.duplicated()]

# %%
dups
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, gender, state, age, date_joined, dependants, fam_status, income]
# Index: []

# %%
# there are no duplicates

# %%
# other checks and things to note:

# data dictionary?

# subsetting?

# indexing?

# none need to be done in this case as numbers are not assigned to stand for something else in this particular dataframe

# %%
# export as a pickel file - customer_data_clean.pkl

customer_data.to_pickle(os.path.join(path, '02 Data','Prepped Data', 'customer_data_clean.pkl'))

# %%
# now that the customer data is clean, we can import that as a pickel file along with the orders_products_merge dataframe

# %%
cust_data_clean = pd.read_pickle(os.path.join(path, '02 Data', 'Prepped Data', 'customer_data_clean.pkl'))

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepped Data', 'orders_products_merged.pkl'))

# %%
# customer data checks

cust_data_clean.head()
# Out:
#   user_id first_name last_name  gender       state  age date_joined  \
# 0   26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1   33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2   65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3  125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4  130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    dependants fam_status  income
# 0           3    married  165665
# 1           0     single   59285
# 2           2    married   99568
# 3           0     single   42049
# 4           1    married   40374

# %%
cust_data_clean.shape
# Out:
# (206209, 10)

# %%
cust_data_clean.isnull().sum()
# Out:
# user_id        0
# first_name     0
# last_name      0
# gender         0
# state          0
# age            0
# date_joined    0
# dependants     0
# fam_status     0
# income         0
# dtype: int64

# %%
# ords_prods_merge checks

ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  time_of_order  \
# 0   2539329        1             1                       2              8
# 1   2398795        1             2                       3              7
# 2    473747        1             3                       3             12
# 3   2254736        1             4                       4              7
# 4    431534        1             5                       4             15
#
#   days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                 100000         196                  1          0   both
# 1                   15.0         196                  1          1   both
# 2                   21.0         196                  1          1   both
# 3                   29.0         196                  1          1   both
# 4                   28.0         196                  1          1   both
#
#    ...    price_range_loc     busiest_day    busiest_days  \
# ...

# %%
ords_prods_merge.shape
# Out:
# (32404859, 24)

# %%
ords_prods_merge.isnull().sum()
# Out:
# order_id                  0
# user_id                   0
# order_number              0
# orders_day_of_the_week    0
# time_of_order             0
# days_since_prior_order    0
# product_id                0
# add_to_cart_order         0
# reordered                 0
# _merge                    0
# product_name              0
# aisle_id                  0
# department_id             0
# prices                    0
# price_range_loc           0
# busiest_day               0
# busiest_days              0
# busiest_period_of_day     0
# max_order                 0
# loyalty_flag              0
# avg_price                 0
# spending_flag             0
# frequency_customer        0
# frequency_flag            0
# dtype: int64

# %%
ords_prods_merge.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_the_week  \
# count  3.240486e+07  3.240486e+07  3.240486e+07            3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01            2.738867e+00
# std    9.872988e+05  5.946610e+04  1.753532e+01            2.090077e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00            0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00            1.000000e+00
# 50%    1.711049e+06  1.026160e+05  1.100000e+01            3.000000e+00
# 75%    2.565499e+06  1.543890e+05  2.400000e+01            5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01            6.000000e+00
#
#        time_of_order    product_id  add_to_cart_order     reordered  \
# count   3.240486e+07  3.240486e+07       3.240486e+07  3.240486e+07
# mean    1.342515e+01  2.559866e+04       8.352547e+00  5.895873e-01
# std     4.246380e+00  1.408400e+04       7.127071e+00  4.919087e-01
# ...

# %%
# user_id needs to be changed to 'str' - a few others could as well...

# %%
ords_prods_merge['user_id'] = ords_prods_merge['user_id'].astype('str')

# %%
# check 

ords_prods_merge.describe()
# Out:
#            order_id  order_number  orders_day_of_the_week  time_of_order  \
# count  3.240486e+07  3.240486e+07            3.240486e+07   3.240486e+07
# mean   1.710745e+06  1.714230e+01            2.738867e+00   1.342515e+01
# std    9.872988e+05  1.753532e+01            2.090077e+00   4.246380e+00
# min    2.000000e+00  1.000000e+00            0.000000e+00   0.000000e+00
# 25%    8.559470e+05  5.000000e+00            1.000000e+00   1.000000e+01
# 50%    1.711049e+06  1.100000e+01            3.000000e+00   1.300000e+01
# 75%    2.565499e+06  2.400000e+01            5.000000e+00   1.600000e+01
# max    3.421083e+06  9.900000e+01            6.000000e+00   2.300000e+01
#
#          product_id  add_to_cart_order     reordered      aisle_id  \
# count  3.240486e+07       3.240486e+07  3.240486e+07  3.240486e+07
# mean   2.559866e+04       8.352547e+00  5.895873e-01  7.119612e+01
# std    1.408400e+04       7.127071e+00  4.919087e-01  3.821139e+01
# ...

# %%
# left merge - customer_data onto the ords_prods_merge on column = user_id

# %%
ords_prods_cust_merge = ords_prods_merge.merge(cust_data_clean, on = 'user_id')

# %%
# checking output

ords_prods_cust_merge.head()
# Out:
#    order_id user_id  order_number  orders_day_of_the_week  time_of_order  \
# 0   2539329       1             1                       2              8
# 1   2398795       1             2                       3              7
# 2    473747       1             3                       3             12
# 3   2254736       1             4                       4              7
# 4    431534       1             5                       4             15
#
#   days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                 100000         196                  1          0   both
# 1                   15.0         196                  1          1   both
# 2                   21.0         196                  1          1   both
# 3                   29.0         196                  1          1   both
# 4                   28.0         196                  1          1   both
#
#    ...         frequency_flag  first_name  last_name  gender    state age  \
# ...

# %%
# Checking value count

ords_prods_cust_merge['_merge'].value_counts()
# Out:
# both    32404859
# Name: _merge, dtype: int64

# %%
# other consistency checks for ords_prods_cust_merge

# %%
ords_prods_cust_merge.isnull().sum()
# Out:
# order_id                  0
# user_id                   0
# order_number              0
# orders_day_of_the_week    0
# time_of_order             0
# days_since_prior_order    0
# product_id                0
# add_to_cart_order         0
# reordered                 0
# _merge                    0
# product_name              0
# aisle_id                  0
# department_id             0
# prices                    0
# price_range_loc           0
# busiest_day               0
# busiest_days              0
# busiest_period_of_day     0
# max_order                 0
# loyalty_flag              0
# avg_price                 0
# spending_flag             0
# frequency_customer        0
# frequency_flag            0
# first_name                0
# last_name                 0
# gender                    0
# state                     0
# age                       0
# date_joined               0
# dependants                0
# fam_status                0
# income                    0
# ...

# %%
ords_prods_cust_merge.shape
# Out:
# (32404859, 33)

# %%
# Export data to pkl

ords_prods_cust_merge.to_pickle(os.path.join(path, '02 Data','Prepped Data', 'ords_prods_cust_merged.pkl'))
